# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 4. Using the pandas `read_csv()` method, read the GDP dataset into your notebook as a DataFrame called `gdp_df`.
gdp_df = pd.read_csv('C:/Users/lilli/Documents/NSS/Python/data/gdp_percapita.csv')

# %%
# 4. Take a look at the first few and last few rows to familiarize yourself with what is contained in this dataset.
gdp_df.head(5)
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2023  1992.424394              NaN
# 1     Afghanistan  2022  1981.710168              NaN
# 2     Afghanistan  2021  2144.166570              NaN
# 3     Afghanistan  2020  2769.685745              NaN
# 4     Afghanistan  2019  2927.245144              NaN

# %%
# 4. Take a look at the first few and last few rows to familiarize yourself with what is contained in this dataset.
gdp_df.tail(5)
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 8214        Zimbabwe  1994  3965.730986              NaN
# 8215        Zimbabwe  1993  3634.750494              NaN
# 8216        Zimbabwe  1992  3649.891947              NaN
# 8217        Zimbabwe  1991  4126.405247              NaN
# 8218        Zimbabwe  1990  4013.299059              NaN

# %%
# 5. How many rows and columns are in `gdp_df`? What are the data types of each column?
gdp_df.shape
# Out:
# (8219, 4)

# %%
# 5. What are the data types of each column?
gdp_df.columns
# Out:
# Index(['Country or Area', 'Year', 'Value', 'Value Footnotes'], dtype='object')

# %%
# 6a. Drop the `Value Footnotes` column
gdp_df_clean = gdp_df.drop(columns = ['Value Footnotes'])

# %%
# Checking 6a
gdp_df_clean.columns
# Out:
# Index(['Country or Area', 'Year', 'Value'], dtype='object')

# %%
# 6b. Rename the remaining three to 'Country', 'Year', and 'GDP_Per_Capita'
gdp_df_clean = gdp_df_clean.rename(columns = {'Country or Area': 'Country', 'Value': 'GDP_Per_Capita'})

# %%
# 7. How many countries have data for all years? Which countries are missing many years of data? 
# Look at the number of observations per year. What do you notice?
gdp_df_clean.Country.value_counts() # This is saying how many years have countries with entries
# Out:
# Country
# Africa Eastern and Southern                           34
# Africa Western and Central                            34
# Albania                                               34
# Andorra                                               34
# Algeria                                               34
# Angola                                                34
# Antigua and Barbuda                                   34
# Bahrain                                               34
# Arab World                                            34
# Argentina                                             34
# Armenia                                               34
# Aruba                                                 34
# Australia                                             34
# Austria                                               34
# Azerbaijan                                            34
# Belgium                                               34
# ...

# %%
pd.set_option('display.max_rows', None) # This is showing you the max rows now

# %%
country_count = gdp_df_clean.groupby('Country')['Year'].count() # This is showing you how many entries each country has, by year
print(country_count)
# Out:
# Country
# Afghanistan                                           24
# Africa Eastern and Southern                           34
# Africa Western and Central                            34
# Albania                                               34
# Algeria                                               34
# Andorra                                               34
# Angola                                                34
# Antigua and Barbuda                                   34
# Arab World                                            34
# Argentina                                             34
# Armenia                                               34
# Aruba                                                 34
# Australia                                             34
# Austria                                               34
# Azerbaijan                                            34
# Bahrain                                               34
# ...

# %%
# 8. In this question, you're going to create some plots to show the distribution of GDP per capita for the year 2020.
# Go to the Python Graph Gallery (https://www.python-graph-gallery.com/) and look at the different types of plots under the Distribution section. 
# Create a histogram, a density plot, a boxplot, and a violin plot. What do you notice when you look at these plots? 
# How do the plots compare and what information can you get out of one type that you can't necessarily get out of the others?
